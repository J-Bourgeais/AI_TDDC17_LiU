# %% [markdown]
# <a href="https://colab.research.google.com/github/J-Bourgeais/AI_TDDC17_LiU/blob/main/planning_lab_stub_sansA_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Planning Lab

# %%
# !pip install --pre unified-planning==1.0.0.95.dev1
# !pip install up_fast_downward==0.3.1
# Out:
# Collecting unified-planning==1.0.0.95.dev1
#   Downloading unified_planning-1.0.0.95.dev1-py3-none-any.whl (643 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 643.0/643.0 kB 11.4 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.10/dist-packages (from unified-planning==1.0.0.95.dev1) (3.1.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from unified-planning==1.0.0.95.dev1) (3.1)
# Collecting ConfigSpace (from unified-planning==1.0.0.95.dev1)
#   Downloading ConfigSpace-0.7.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 81.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from ConfigSpace->unified-planning==1.0.0.95.dev1) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from ConfigSpace->unified-planning==1.0.0.95.dev1) (1.11.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from ConfigSpace->unified-planning==1.0.0.95.dev1) (4.5.0)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from ConfigSpace->unified-planning==1.0.0.95.dev1) (10.1.0)
# Installing collected packages: ConfigSpace, unified-planning
# Successfully installed ConfigSpace-0.7.1 unified-planning-1.0.0.95.dev1
# Collecting up_fast_downward==0.3.1
#   Downloading up_fast_downward-0.3.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 MB 17.6 MB/s eta 0:00:00
# Installing collected packages: up_fast_downward
# Successfully installed up_fast_downward-0.3.1

# %%
# !pip install matplotlib==3.7.1  # for visualisation in this notebook
# Out:
# Requirement already satisfied: matplotlib==3.7.1 in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1) (0.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib==3.7.1) (1.16.0)

# %%
from unified_planning.shortcuts import *

import unified_planning as up

up.shortcuts.get_environment().credits_stream = None

# %% [markdown]
# ## Part (a): Model the Task
#
# The code below models a simpler version of the Household Robot domain with two rooms and one open door between them. The robot is in room A initially and needs to move to room B. You can use it as a starting point for your own solution to the full Household Robot task.

# %%
def get_planning_task():
    # Declare user types.
    Room = UserType("Room")
    Door = UserType("Door")
    Key = UserType("Key")

    # Declare predicates.
    robot_in = up.model.Fluent("robot_in", BoolType(), r=Room)
    key_in = up.model.Fluent("key_in", BoolType(), k=Key, r=Room)
    robot_has_key = up.model.Fluent("robot_has_key", BoolType(), k=Key)
    door_is_open = up.model.Fluent("door_is_open", BoolType(), d=Door)
    connected = up.model.Fluent("connected", BoolType(), r1=Room, d=Door, r2=Room)
    room_has_door = up.model.Fluent("room_has_door", BoolType(), r=Room, d=Door)
    #Maybe add predicates for everything key' related

    # Add (typed) objects to problem.
    problem = up.model.Problem("household")

    def get_room(room):
        return up.model.Object(f"room{room}", Room)

    def get_door(door):
        return up.model.Object(f"door{door}", Door)

    def get_key(key):
        return up.model.Object(f"key{key}", Key)

    Kitchen = get_room("Kitchen")
    LivingRoom = get_room("LivingRoom")
    Corridor = get_room("Corridor")
    Lobby = get_room("Lobby")
    Bathroom = get_room("Bathroom")
    Outside = get_room("Outside")
    rooms = [Kitchen, LivingRoom, Corridor, Bathroom, Lobby, Outside]

    doorK = get_door("K")
    doorL = get_door("L")
    doorB = get_door("B")
    doorC = get_door("C")
    doorF = get_door("F")
    doors = [doorK, doorL, doorB, doorC, doorF]

    keyK = get_key("K");
    keyL = get_key("L");
    keyB = get_key("B");
    keyC = get_key("C");
    keyF = get_key("F");
    keyAll = get_key("All");
    keys = [keyK, keyL, keyB, keyC, keyF, keyAll]

    problem.add_objects(rooms)
    problem.add_objects(doors)
    problem.add_objects(keys)

    connections = [
        (Kitchen, doorK, LivingRoom), (LivingRoom, doorL, Corridor), (Corridor, doorB, Bathroom), (Corridor, doorC, Lobby), (Lobby, doorF, Outside)
    ]

    rooms_and_doors = []
    for room1, door, room2 in connections:
        rooms_and_doors.append((room1, door))
        rooms_and_doors.append((room2, door))

    # Specify the initial state.
    problem.add_fluent(robot_in, default_initial_value=False)
    problem.add_fluent(connected, default_initial_value=False)
    problem.add_fluent(room_has_door, default_initial_value=False)
    problem.add_fluent(key_in, default_initial_value=False)
    problem.add_fluent(robot_has_key, default_initial_value=False)
    problem.add_fluent(door_is_open, default_initial_value=False)

    #add for the others
    problem.set_initial_value(robot_in(LivingRoom), True)
  #Set where keys are
    problem.set_initial_value(key_in(keyK, LivingRoom), True)
    problem.set_initial_value(key_in(keyL, LivingRoom), True)
    problem.set_initial_value(key_in(keyB, Corridor), True)
    problem.set_initial_value(key_in(keyF, Bathroom), True)
    problem.set_initial_value(key_in(keyC, Bathroom), True)
    problem.set_initial_value(key_in(keyAll, Kitchen), True)

    for room1, door, room2 in connections:
        problem.set_initial_value(connected(room1, door, room2), True)
        problem.set_initial_value(connected(room2, door, room1), True)
    for room, door in rooms_and_doors:
        problem.set_initial_value(room_has_door(room, door), True)

    # Add actions

#MOVE BETWEEN ROOM
    #Move from Kitchen to LivingRoom
    move_K_LR = up.model.InstantaneousAction("move_K_LR")
    move_K_LR.add_precondition(robot_in(Kitchen))
    move_K_LR.add_precondition(connected(Kitchen, doorK, LivingRoom))
    move_K_LR.add_precondition(door_is_open(doorK))
    move_K_LR.add_effect(robot_in(Kitchen), False)
    move_K_LR.add_effect(robot_in(LivingRoom), True)
    problem.add_action(move_K_LR)

    #Move from LivingRoom to Kitchen
    move_LR_K = up.model.InstantaneousAction("move_LR_K")
    move_LR_K.add_precondition(robot_in(LivingRoom))
    move_LR_K.add_precondition(connected(Kitchen, doorK, LivingRoom))
    move_LR_K.add_precondition(door_is_open(doorK))
    move_LR_K.add_effect(robot_in(Kitchen), True)
    move_LR_K.add_effect(robot_in(LivingRoom), False)
    problem.add_action(move_LR_K)

    #Move from LivingRoom to Corridor
    move_LR_C = up.model.InstantaneousAction("move_LR_C")
    move_LR_C.add_precondition(robot_in(LivingRoom))
    move_LR_C.add_precondition(connected(LivingRoom, doorL, Corridor))
    move_LR_C.add_precondition(door_is_open(doorL))
    move_LR_C.add_effect(robot_in(LivingRoom), False)
    move_LR_C.add_effect(robot_in(Corridor), True)
    problem.add_action(move_LR_C)

    #Move from Corridor to LivingRoom
    move_C_LR = up.model.InstantaneousAction("move_C_LR")
    move_C_LR.add_precondition(robot_in(Corridor))
    move_C_LR.add_precondition(connected(LivingRoom, doorL, Corridor))
    move_C_LR.add_precondition(door_is_open(doorL))
    move_C_LR.add_effect(robot_in(LivingRoom), True)
    move_C_LR.add_effect(robot_in(Corridor), False)
    problem.add_action(move_C_LR)

    #Move from Corridor to Bathroom
    move_C_B = up.model.InstantaneousAction("move_C_B")
    move_C_B.add_precondition(robot_in(Corridor))
    move_C_B.add_precondition(connected(Corridor, doorB, Bathroom))
    move_C_B.add_precondition(door_is_open(doorB))
    move_C_B.add_effect(robot_in(Corridor), False)
    move_C_B.add_effect(robot_in(Bathroom), True)
    problem.add_action(move_C_B)

    #Move from Bathroom to Corridor
    move_B_C = up.model.InstantaneousAction("move_B_C")
    move_B_C.add_precondition(robot_in(Bathroom))
    move_B_C.add_precondition(connected(Corridor, doorB, Bathroom))
    move_B_C.add_precondition(door_is_open(doorB))
    move_B_C.add_effect(robot_in(Corridor), True)
    move_B_C.add_effect(robot_in(Bathroom), False)
    problem.add_action(move_B_C)

    #Move from Corridor to Lobby
    move_C_L = up.model.InstantaneousAction("move_C_L")
    move_C_L.add_precondition(robot_in(Corridor))
    move_C_L.add_precondition(connected(Corridor, doorC, Lobby))
    move_C_L.add_precondition(door_is_open(doorC))
    move_C_L.add_effect(robot_in(Corridor), False)
    move_C_L.add_effect(robot_in(Lobby), True)
    problem.add_action(move_C_L)

    #Move from Lobby to Corridor
    move_L_C = up.model.InstantaneousAction("move_L_C")
    move_L_C.add_precondition(robot_in(Lobby))
    move_L_C.add_precondition(connected(Corridor, doorC, Lobby))
    move_L_C.add_precondition(door_is_open(doorC))
    move_L_C.add_effect(robot_in(Corridor), True)
    move_L_C.add_effect(robot_in(Lobby), False)
    problem.add_action(move_L_C)

#PICK_A_KEY
    #Pick the key K
    Pick_Key_K = up.model.InstantaneousAction("Pick_Key_K")
    Pick_Key_K.add_precondition(robot_in(LivingRoom))
    Pick_Key_K.add_precondition(key_in(keyK, LivingRoom))
    Pick_Key_K.add_effect(robot_has_key(keyK), True)
    Pick_Key_K.add_effect(key_in(keyK, LivingRoom), False)
    problem.add_action(Pick_Key_K)

    #faut qu'il l'ai pas deja

    #Pick the key L
    Pick_Key_L = up.model.InstantaneousAction("Pick_Key_L")
    Pick_Key_L.add_precondition(robot_in(LivingRoom))
    Pick_Key_L.add_precondition(key_in(keyL, LivingRoom))
    Pick_Key_L.add_effect(robot_has_key(keyL), True)
    Pick_Key_L.add_effect(key_in(keyL, LivingRoom), False)
    problem.add_action(Pick_Key_L)

    #Pick the key all
    Pick_Key_all = up.model.InstantaneousAction("Pick_Key_all")
    Pick_Key_all.add_precondition(robot_in(Kitchen))
    Pick_Key_all.add_precondition(key_in(keyAll, Kitchen))
    Pick_Key_all.add_effect(robot_has_key(keyAll), True)
    Pick_Key_all.add_effect(key_in(keyAll, Kitchen), False)
    problem.add_action(Pick_Key_all)

    #Pick the key B
    Pick_Key_B = up.model.InstantaneousAction("Pick_Key_B")
    Pick_Key_B.add_precondition(robot_in(Corridor))
    Pick_Key_B.add_precondition(key_in(keyB, Corridor))
    Pick_Key_B.add_effect(robot_has_key(keyB), True)
    Pick_Key_B.add_effect(key_in(keyB, Corridor), False)
    problem.add_action(Pick_Key_B)

    #Pick the key F
    Pick_Key_F = up.model.InstantaneousAction("Pick_Key_F")
    Pick_Key_F.add_precondition(robot_in(Bathroom))
    Pick_Key_F.add_precondition(key_in(keyF, Bathroom))
    Pick_Key_F.add_effect(robot_has_key(keyF), True)
    Pick_Key_F.add_effect(key_in(keyF, Bathroom), False)
    problem.add_action(Pick_Key_F)

    #Pick the key C
    Pick_Key_C = up.model.InstantaneousAction("Pick_Key_C")
    Pick_Key_C.add_precondition(robot_in(Bathroom))
    Pick_Key_C.add_precondition(key_in(keyC, Bathroom))
    Pick_Key_C.add_effect(robot_has_key(keyC), True)
    Pick_Key_C.add_effect(key_in(keyC, Bathroom), False)
    problem.add_action(Pick_Key_C)

#OPEN A DOOR
    #Open the door K
    Open_K = up.model.InstantaneousAction("Open_K")
    Open_K.add_precondition(robot_has_key(keyK).Or(robot_has_key(keyAll)))
    Open_K.add_precondition(robot_in(Kitchen).Or(robot_in(LivingRoom)))
    Open_K.add_effect(door_is_open(doorK), True)
    problem.add_action(Open_K)

    #Open the door L
    Open_L = up.model.InstantaneousAction("Open_L")
    Open_L.add_precondition(robot_has_key(keyL).Or(robot_has_key(keyAll)))
    Open_L.add_precondition(robot_in(LivingRoom).Or(robot_in(Corridor)))
    Open_L.add_effect(door_is_open(doorL), True)
    problem.add_action(Open_L)

    #Open the door B
    Open_B = up.model.InstantaneousAction("Open_B")
    Open_B.add_precondition(robot_has_key(keyB).Or(robot_has_key(keyAll)))
    Open_B.add_precondition(robot_in(Corridor).Or(robot_in(Bathroom)))
    Open_B.add_effect(door_is_open(doorB), True)
    problem.add_action(Open_B)

    #Open the door C
    Open_C = up.model.InstantaneousAction("Open_C")
    Open_C.add_precondition(robot_has_key(keyC).Or(robot_has_key(keyAll)))
    Open_C.add_precondition(robot_in(Corridor).Or(robot_in(Lobby)))
    Open_C.add_effect(door_is_open(doorC), True)
    problem.add_action(Open_C)

    #Open the door F
    Open_F = up.model.InstantaneousAction("Open_F")
    Open_F.add_precondition(robot_has_key(keyF).Or(robot_has_key(keyAll)))
    Open_F.add_precondition(robot_in(Lobby))
    Open_F.add_effect(door_is_open(doorF), True)
    problem.add_action(Open_F)


    # Specify the goal.
    problem.add_goal(door_is_open(doorF))

    # We want to minimize the plan cost.
    problem.add_quality_metric(MinimizeActionCosts({}, default=Int(1)))
    return problem

problem = get_planning_task()
#print(problem)

# %% [markdown]
# ## Part (b): Find a (possibly suboptimal) plan
#
# Solve the task with greedy best-first search using the FF heuristic. The example code below uses the h^add heuristic. You need to inspect the output to stdout to see the heuristic value of the initial state.

# %%
params = {
    "fast_downward_search_config": "eager_greedy([add()])"
}

with OneshotPlanner(name="fast-downward", params=params) as planner:
    result = planner.solve(problem, output_stream=sys.stdout)
    if result.status == up.engines.PlanGenerationResultStatus.SOLVED_SATISFICING:
        print("Found a plan of length:", len(result.plan.actions))
        print(result.plan)
        with PlanValidator() as validator:
            val_result = validator.validate(problem, result.plan)
            print("Plan cost:", val_result.metric_evaluations)
    else:
        print("No plan found.")
# Out:
# INFO     planner time limit: None
# INFO     planner memory limit: None
#
# INFO     Running translator.
# INFO     translator stdin: None
# INFO     translator time limit: None
# INFO     translator memory limit: None
# INFO     translator command line string: /usr/bin/python3 /usr/local/lib/python3.10/dist-packages/up_fast_downward/downward/builds/release/bin/translate/translate.py /tmp/tmpowk_mfqf/domain.pddl /tmp/tmpowk_mfqf/problem.pddl --sas-file output.sas
# Parsing...
# Parsing: [0.000s CPU, 0.006s wall-clock]
# Normalizing task... [0.000s CPU, 0.001s wall-clock]
# Instantiating...
# Generating Datalog program... [0.000s CPU, 0.001s wall-clock]
# Normalizing Datalog program...
# Normalizing Datalog program: [0.000s CPU, 0.001s wall-clock]
# Preparing model... [0.000s CPU, 0.001s wall-clock]
# Generated 65 rules.
# Computing model... [0.000s CPU, 0.001s wall-clock]
# 126 relevant atoms
# 0 auxiliary atoms
# 126 final queue length
# 143 total queue pushes
# Completing instantiation... [0.000s CPU, 0.001s wall-clock]
# Instantiating: [0.010s CPU, 0.007s wall-clock]
# Computing fact groups...
# Finding invariants...
# 9 initial candidates
# Finding invariants: [0.000s CPU, 0.001s wall-clock]
# Checking invariant weight... [0.000s CPU, 0.000s wall-clock]
# Instantiating groups... [0.000s CPU, 0.000s wall-clock]
# Collecting mutex groups... [0.000s CPU, 0.000s wall-clock]
# Choosing groups...
# 5 uncovered facts
# Choosing groups: [0.000s CPU, 0.000s wall-clock]
# Building translation key... [0.000s CPU, 0.000s wall-clock]
# Computing fact groups: [0.000s CPU, 0.004s wall-clock]
# Building STRIPS to SAS dictionary... [0.000s CPU, 0.000s wall-clock]
# Building dictionary for full mutex groups... [0.000s CPU, 0.000s wall-clock]
# Building mutex information...
# Building mutex information: [0.000s CPU, 0.000s wall-clock]
# Translating task...
# Processing axioms...
# Simplifying axioms... [0.000s CPU, 0.000s wall-clock]
# Translator axioms removed by simplifying: 0
# Computing negative axioms... [0.000s CPU, 0.000s wall-clock]
# Processing axioms: [0.000s CPU, 0.000s wall-clock]
# Translating task: [0.000s CPU, 0.002s wall-clock]
# 0 effect conditions simplified
# 0 implied preconditions added
# Detecting unreachable propositions...
# 0 operators removed
# 0 axioms removed
# 7 propositions removed
# Detecting unreachable propositions: [0.000s CPU, 0.001s wall-clock]
# Reordering and filtering variables...
# 12 of 12 variables necessary.
# 0 of 7 mutex groups necessary.
# 32 of 32 operators necessary.
# 0 of 0 axiom rules necessary.
# Reordering and filtering variables: [0.000s CPU, 0.001s wall-clock]
# Translator variables: 12
# Translator derived variables: 0
# Translator facts: 27
# Translator goal facts: 1
# Translator mutex groups: 0
# Translator total mutex groups size: 0
# Translator operators: 32
# Translator axioms: 0
# Translator task size: 168
# Translator peak memory: 31476 KB
# Writing output... [0.000s CPU, 0.001s wall-clock]
# Done! [0.010s CPU, 0.024s wall-clock]
# translate exit code: 0
#
# INFO     Running search (release).
# INFO     search stdin: output.sas
# INFO     search time limit: None
# INFO     search memory limit: None
# INFO     search command line string: /usr/local/lib/python3.10/dist-packages/up_fast_downward/downward/builds/release/bin/downward --search 'eager_greedy([add()])' --internal-plan-file /tmp/tmpowk_mfqf/plan.txt < output.sas
# [t=0.00210764s, 10804 KB] reading input...
# [t=0.00271573s, 10804 KB] done reading input!
# [t=0.00479009s, 11060 KB] Simplifying 32 unary operators... done! [32 unary operators]
# [t=0.0049195s, 11060 KB] time to simplify: 0.000182119s
# [t=0.00498304s, 11060 KB] Initializing additive heuristic...
# [t=0.00503955s, 11060 KB] Building successor generator...done!
# [t=0.00517888s, 11060 KB] peak memory difference for successor generator creation: 0 KB
# [t=0.00520479s, 11060 KB] time for successor generation creation: 4.359e-05s
# [t=0.0052392s, 11060 KB] Variables: 12
# [t=0.00527304s, 11060 KB] FactPairs: 27
# [t=0.00529791s, 11060 KB] Bytes per state: 4
# [t=0.00535089s, 11060 KB] Conducting best first search without reopening closed nodes, (real) bound = 2147483647
# [t=0.00544821s, 11060 KB] New best heuristic value for add(): 17
# [t=0.0054829s, 11060 KB] g=0, 1 evaluated, 0 expanded
# [t=0.00551384s, 11060 KB] Initial heuristic value for add(): 17
# [t=0.00554721s, 11060 KB] pruning method: none
# [t=0.00558998s, 11060 KB] New best heuristic value for add(): 15
# [t=0.00561654s, 11060 KB] g=1, 2 evaluated, 1 expanded
# [t=0.00565525s, 11060 KB] New best heuristic value for add(): 13
# [t=0.00567988s, 11060 KB] g=2, 4 evaluated, 2 expanded
# [t=0.00572007s, 11060 KB] New best heuristic value for add(): 11
# [t=0.00574161s, 11060 KB] g=3, 6 evaluated, 3 expanded
# [t=0.00578043s, 11060 KB] New best heuristic value for add(): 9
# [t=0.00580697s, 11060 KB] g=4, 8 evaluated, 4 expanded
# [t=0.00586123s, 11060 KB] New best heuristic value for add(): 7
# [t=0.00589354s, 11060 KB] g=6, 12 evaluated, 6 expanded
# [t=0.00592495s, 11060 KB] New best heuristic value for add(): 5
# [t=0.00596808s, 11060 KB] g=7, 13 evaluated, 7 expanded
# [t=0.00600583s, 11060 KB] New best heuristic value for add(): 3
# [t=0.00603197s, 11060 KB] g=8, 14 evaluated, 8 expanded
# [t=0.00606957s, 11060 KB] New best heuristic value for add(): 2
# [t=0.00609829s, 11060 KB] g=9, 16 evaluated, 9 expanded
# [t=0.00614389s, 11060 KB] New best heuristic value for add(): 1
# [t=0.00617227s, 11060 KB] g=10, 20 evaluated, 10 expanded
# [t=0.00620487s, 11060 KB] New best heuristic value for add(): 0
# [t=0.00623159s, 11060 KB] g=11, 22 evaluated, 11 expanded
# [t=0.00625998s, 11060 KB] Solution found!
# [t=0.00628903s, 11060 KB] Actual search time: 0.000739398s
# pick_key_k  (1)
# open_k  (1)
# pick_key_l  (1)
# open_l  (1)
# move_lr_k  (1)
# pick_key_all  (1)
# move_k_lr  (1)
# move_lr_c  (1)
# open_c  (1)
# move_c_l  (1)
# open_f  (1)
# [t=0.00631629s, 11060 KB] Plan length: 11 step(s).
# [t=0.00631629s, 11060 KB] Plan cost: 11
# [t=0.00631629s, 11060 KB] Expanded 12 state(s).
# [t=0.00631629s, 11060 KB] Reopened 0 state(s).
# [t=0.00631629s, 11060 KB] Evaluated 22 state(s).
# [t=0.00631629s, 11060 KB] Evaluations: 22
# [t=0.00631629s, 11060 KB] Generated 42 state(s).
# [t=0.00631629s, 11060 KB] Dead ends: 0 state(s).
# [t=0.00631629s, 11060 KB] Number of registered states: 22
# [t=0.00631629s, 11060 KB] Int hash set load factor: 22/32 = 0.6875
# [t=0.00631629s, 11060 KB] Int hash set resizes: 5
# [t=0.00631629s, 11060 KB] Search time: 0.000966701s
# [t=0.00631629s, 11060 KB] Total time: 0.00631629s
# Solution found.
# Peak memory: 11060 KB
# Remove intermediate file output.sas
# search exit code: 0
#
# INFO     Planner time: 0.15s
# Found a plan of length: 11
# SequentialPlan:
#     Pick_Key_K
#     Open_K
#     Pick_Key_L
#     Open_L
#     move_LR_K
#     Pick_Key_all
#     move_K_LR
#     move_LR_C
#     Open_C
#     move_C_L
#     Open_F
# Plan cost: {minimize actions-cost: {'default': 1}: 11}

# %%
params = {
    "fast_downward_search_config": "eager_greedy([ff()])"
}

with OneshotPlanner(name="fast-downward", params=params) as planner:
    result = planner.solve(problem, output_stream=sys.stdout)
    if result.status == up.engines.PlanGenerationResultStatus.SOLVED_SATISFICING:
        print("Found a plan of length:", len(result.plan.actions))
        print(result.plan)
        with PlanValidator() as validator:
            val_result = validator.validate(problem, result.plan)
            print("Plan cost:", val_result.metric_evaluations)
    else:
        print("No plan found.")
# Out:
# INFO     planner time limit: None
# INFO     planner memory limit: None
#
# INFO     Running translator.
# INFO     translator stdin: None
# INFO     translator time limit: None
# INFO     translator memory limit: None
# INFO     translator command line string: /usr/bin/python3 /usr/local/lib/python3.10/dist-packages/up_fast_downward/downward/builds/release/bin/translate/translate.py /tmp/tmpwoxix9z0/domain.pddl /tmp/tmpwoxix9z0/problem.pddl --sas-file output.sas
# Parsing...
# Parsing: [0.000s CPU, 0.004s wall-clock]
# Normalizing task... [0.000s CPU, 0.001s wall-clock]
# Instantiating...
# Generating Datalog program... [0.000s CPU, 0.001s wall-clock]
# Normalizing Datalog program...
# Normalizing Datalog program: [0.000s CPU, 0.002s wall-clock]
# Preparing model... [0.000s CPU, 0.002s wall-clock]
# Generated 65 rules.
# Computing model... [0.000s CPU, 0.001s wall-clock]
# 126 relevant atoms
# 0 auxiliary atoms
# 126 final queue length
# 143 total queue pushes
# Completing instantiation... [0.000s CPU, 0.001s wall-clock]
# Instantiating: [0.000s CPU, 0.007s wall-clock]
# Computing fact groups...
# Finding invariants...
# 9 initial candidates
# Finding invariants: [0.000s CPU, 0.002s wall-clock]
# Checking invariant weight... [0.000s CPU, 0.000s wall-clock]
# Instantiating groups... [0.000s CPU, 0.001s wall-clock]
# Collecting mutex groups... [0.000s CPU, 0.000s wall-clock]
# Choosing groups...
# 5 uncovered facts
# Choosing groups: [0.000s CPU, 0.000s wall-clock]
# Building translation key... [0.000s CPU, 0.000s wall-clock]
# Computing fact groups: [0.000s CPU, 0.004s wall-clock]
# Building STRIPS to SAS dictionary... [0.000s CPU, 0.000s wall-clock]
# Building dictionary for full mutex groups... [0.000s CPU, 0.000s wall-clock]
# Building mutex information...
# Building mutex information: [0.000s CPU, 0.000s wall-clock]
# Translating task...
# Processing axioms...
# Simplifying axioms... [0.000s CPU, 0.000s wall-clock]
# Translator axioms removed by simplifying: 0
# Computing negative axioms... [0.000s CPU, 0.000s wall-clock]
# Processing axioms: [0.000s CPU, 0.000s wall-clock]
# Translating task: [0.000s CPU, 0.002s wall-clock]
# 0 effect conditions simplified
# 0 implied preconditions added
# Detecting unreachable propositions...
# 0 operators removed
# 0 axioms removed
# 7 propositions removed
# Detecting unreachable propositions: [0.000s CPU, 0.001s wall-clock]
# Reordering and filtering variables...
# 12 of 12 variables necessary.
# 0 of 7 mutex groups necessary.
# 32 of 32 operators necessary.
# 0 of 0 axiom rules necessary.
# Reordering and filtering variables: [0.000s CPU, 0.001s wall-clock]
# Translator variables: 12
# Translator derived variables: 0
# Translator facts: 27
# Translator goal facts: 1
# Translator mutex groups: 0
# Translator total mutex groups size: 0
# Translator operators: 32
# Translator axioms: 0
# Translator task size: 168
# Translator peak memory: 31476 KB
# Writing output... [0.000s CPU, 0.001s wall-clock]
# Done! [0.010s CPU, 0.022s wall-clock]
# translate exit code: 0
#
# INFO     Running search (release).
# INFO     search stdin: output.sas
# INFO     search time limit: None
# INFO     search memory limit: None
# INFO     search command line string: /usr/local/lib/python3.10/dist-packages/up_fast_downward/downward/builds/release/bin/downward --search 'eager_greedy([ff()])' --internal-plan-file /tmp/tmpwoxix9z0/plan.txt < output.sas
# [t=0.0021259s, 10804 KB] reading input...
# [t=0.00269703s, 10804 KB] done reading input!
# [t=0.004594s, 11060 KB] Simplifying 32 unary operators... done! [32 unary operators]
# [t=0.0047162s, 11060 KB] time to simplify: 0.000173648s
# [t=0.00477891s, 11060 KB] Initializing additive heuristic...
# [t=0.00480917s, 11060 KB] Initializing FF heuristic...
# [t=0.00486068s, 11060 KB] Building successor generator...done!
# [t=0.0049825s, 11060 KB] peak memory difference for successor generator creation: 0 KB
# [t=0.00502034s, 11060 KB] time for successor generation creation: 4.1296e-05s
# [t=0.00505131s, 11060 KB] Variables: 12
# [t=0.00509383s, 11060 KB] FactPairs: 27
# [t=0.00512047s, 11060 KB] Bytes per state: 4
# [t=0.00518014s, 11060 KB] Conducting best first search without reopening closed nodes, (real) bound = 2147483647
# [t=0.00524462s, 11060 KB] New best heuristic value for ff(): 10
# [t=0.00527775s, 11060 KB] g=0, 1 evaluated, 0 expanded
# [t=0.00531194s, 11060 KB] Initial heuristic value for ff(): 10
# [t=0.00535065s, 11060 KB] pruning method: none
# [t=0.00539631s, 11060 KB] New best heuristic value for ff(): 9
# [t=0.00542148s, 11060 KB] g=1, 2 evaluated, 1 expanded
# [t=0.00546068s, 11060 KB] New best heuristic value for ff(): 8
# [t=0.00548677s, 11060 KB] g=2, 4 evaluated, 2 expanded
# [t=0.00553786s, 11060 KB] New best heuristic value for ff(): 7
# [t=0.00557026s, 11060 KB] g=3, 6 evaluated, 3 expanded
# [t=0.00561106s, 11060 KB] New best heuristic value for ff(): 6
# [t=0.0056399s, 11060 KB] g=4, 8 evaluated, 4 expanded
# [t=0.00568809s, 11060 KB] New best heuristic value for ff(): 5
# [t=0.00571522s, 11060 KB] g=6, 12 evaluated, 6 expanded
# [t=0.00574144s, 11060 KB] New best heuristic value for ff(): 4
# [t=0.00576929s, 11060 KB] g=7, 13 evaluated, 7 expanded
# [t=0.00580332s, 11060 KB] New best heuristic value for ff(): 3
# [t=0.00582996s, 11060 KB] g=8, 14 evaluated, 8 expanded
# [t=0.00586439s, 11060 KB] New best heuristic value for ff(): 2
# [t=0.00588999s, 11060 KB] g=9, 16 evaluated, 9 expanded
# [t=0.00593319s, 11060 KB] New best heuristic value for ff(): 1
# [t=0.00596119s, 11060 KB] g=10, 20 evaluated, 10 expanded
# [t=0.0060099s, 11060 KB] New best heuristic value for ff(): 0
# [t=0.00604036s, 11060 KB] g=11, 22 evaluated, 11 expanded
# [t=0.00606594s, 11060 KB] Solution found!
# [t=0.00609263s, 11060 KB] Actual search time: 0.00073804s
# pick_key_k  (1)
# open_k  (1)
# pick_key_l  (1)
# open_l  (1)
# move_lr_k  (1)
# pick_key_all  (1)
# move_k_lr  (1)
# move_lr_c  (1)
# open_c  (1)
# move_c_l  (1)
# open_f  (1)
# [t=0.00612384s, 11060 KB] Plan length: 11 step(s).
# [t=0.00612384s, 11060 KB] Plan cost: 11
# [t=0.00612384s, 11060 KB] Expanded 12 state(s).
# [t=0.00612384s, 11060 KB] Reopened 0 state(s).
# [t=0.00612384s, 11060 KB] Evaluated 22 state(s).
# [t=0.00612384s, 11060 KB] Evaluations: 22
# [t=0.00612384s, 11060 KB] Generated 42 state(s).
# [t=0.00612384s, 11060 KB] Dead ends: 0 state(s).
# [t=0.00612384s, 11060 KB] Number of registered states: 22
# [t=0.00612384s, 11060 KB] Int hash set load factor: 22/32 = 0.6875
# [t=0.00612384s, 11060 KB] Int hash set resizes: 5
# [t=0.00612384s, 11060 KB] Search time: 0.000944962s
# [t=0.00612384s, 11060 KB] Total time: 0.00612384s
# Solution found.
# Peak memory: 11060 KB
# Remove intermediate file output.sas
# search exit code: 0
#
# INFO     Planner time: 0.17s
# Found a plan of length: 11
# SequentialPlan:
#     Pick_Key_K
#     Open_K
#     Pick_Key_L
#     Open_L
#     move_LR_K
#     Pick_Key_all
#     move_K_LR
#     move_LR_C
#     Open_C
#     move_C_L
#     Open_F
# Plan cost: {minimize actions-cost: {'default': 1}: 11}

# %% [markdown]
# ## Part (c): Find an optimal plan+
#
# Solve the task with A* using the `iPDB` heuristic.

# %%
params = {
    "fast_downward_search_config": "astar(ipdb())"
}

with OneshotPlanner(name="fast-downward", params=params) as planner:
    result = planner.solve(problem, output_stream=sys.stdout)
    if result.status == up.engines.PlanGenerationResultStatus.SOLVED_SATISFICING:
        print("Found a plan of length:", len(result.plan.actions))
        print(result.plan)
        with PlanValidator() as validator:
            val_result = validator.validate(problem, result.plan)
            print("Plan cost:", val_result.metric_evaluations)
    else:
        print("No plan found.")
# Out:
# INFO     planner time limit: None
# INFO     planner memory limit: None
#
# INFO     Running translator.
# INFO     translator stdin: None
# INFO     translator time limit: None
# INFO     translator memory limit: None
# INFO     translator command line string: /usr/bin/python3 /usr/local/lib/python3.10/dist-packages/up_fast_downward/downward/builds/release/bin/translate/translate.py /tmp/tmpaes6zbls/domain.pddl /tmp/tmpaes6zbls/problem.pddl --sas-file output.sas
# Parsing...
# Parsing: [0.000s CPU, 0.004s wall-clock]
# Normalizing task... [0.000s CPU, 0.001s wall-clock]
# Instantiating...
# Generating Datalog program... [0.000s CPU, 0.001s wall-clock]
# Normalizing Datalog program...
# Normalizing Datalog program: [0.010s CPU, 0.001s wall-clock]
# Preparing model... [0.000s CPU, 0.001s wall-clock]
# Generated 65 rules.
# Computing model... [0.000s CPU, 0.001s wall-clock]
# 126 relevant atoms
# 0 auxiliary atoms
# 126 final queue length
# 143 total queue pushes
# Completing instantiation... [0.000s CPU, 0.001s wall-clock]
# Instantiating: [0.010s CPU, 0.007s wall-clock]
# Computing fact groups...
# Finding invariants...
# 9 initial candidates
# Finding invariants: [0.000s CPU, 0.002s wall-clock]
# Checking invariant weight... [0.000s CPU, 0.000s wall-clock]
# Instantiating groups... [0.000s CPU, 0.000s wall-clock]
# Collecting mutex groups... [0.000s CPU, 0.000s wall-clock]
# Choosing groups...
# 5 uncovered facts
# Choosing groups: [0.000s CPU, 0.000s wall-clock]
# Building translation key... [0.000s CPU, 0.000s wall-clock]
# Computing fact groups: [0.000s CPU, 0.005s wall-clock]
# Building STRIPS to SAS dictionary... [0.000s CPU, 0.000s wall-clock]
# Building dictionary for full mutex groups... [0.000s CPU, 0.000s wall-clock]
# Building mutex information...
# Building mutex information: [0.000s CPU, 0.000s wall-clock]
# Translating task...
# Processing axioms...
# Simplifying axioms... [0.000s CPU, 0.000s wall-clock]
# Translator axioms removed by simplifying: 0
# Computing negative axioms... [0.000s CPU, 0.000s wall-clock]
# Processing axioms: [0.000s CPU, 0.000s wall-clock]
# Translating task: [0.000s CPU, 0.002s wall-clock]
# 0 effect conditions simplified
# 0 implied preconditions added
# Detecting unreachable propositions...
# 0 operators removed
# 0 axioms removed
# 7 propositions removed
# Detecting unreachable propositions: [0.000s CPU, 0.001s wall-clock]
# Reordering and filtering variables...
# 12 of 12 variables necessary.
# 0 of 7 mutex groups necessary.
# 32 of 32 operators necessary.
# 0 of 0 axiom rules necessary.
# Reordering and filtering variables: [0.000s CPU, 0.001s wall-clock]
# Translator variables: 12
# Translator derived variables: 0
# Translator facts: 27
# Translator goal facts: 1
# Translator mutex groups: 0
# Translator total mutex groups size: 0
# Translator operators: 32
# Translator axioms: 0
# Translator task size: 168
# Translator peak memory: 31476 KB
# Writing output... [0.010s CPU, 0.001s wall-clock]
# Done! [0.020s CPU, 0.024s wall-clock]
# translate exit code: 0
#
# INFO     Running search (release).
# INFO     search stdin: output.sas
# INFO     search time limit: None
# INFO     search memory limit: None
# INFO     search command line string: /usr/local/lib/python3.10/dist-packages/up_fast_downward/downward/builds/release/bin/downward --search 'astar(ipdb())' --internal-plan-file /tmp/tmpaes6zbls/plan.txt < output.sas
# [t=0.00209112s, 10804 KB] reading input...
# [t=0.00267373s, 10804 KB] done reading input!
# [t=0.00497694s, 11060 KB] Initializing canonical PDB heuristic...
# [t=0.00505534s, 11060 KB] Generating patterns using: hill climbing pattern collection generator
# [t=0.00514905s, 11060 KB] Done calculating initial pattern collection: 7.6817e-05s
# [t=0.00520671s, 11060 KB] Average operator cost: 1
# [t=0.00525034s, 11060 KB] building causal graph...done! [t=8.439e-05s]
# [t=0.00540489s, 11060 KB] Done calculating initial candidate PDBs
# [t=0.00688434s, 11060 KB] found a better pattern with improvement 1000
# [t=0.00922639s, 11060 KB] found a better pattern with improvement 1000
# [t=0.0124913s, 11060 KB] found a better pattern with improvement 248
# [t=0.0168025s, 11060 KB] Improvement below threshold. Stop hill climbing.
# [t=0.0168789s, 11060 KB] Hill climbing iterations: 4
# [t=0.0169489s, 11060 KB] Hill climbing generated patterns: 21
# [t=0.0169916s, 11060 KB] Hill climbing rejected patterns: 0
# [t=0.0170216s, 11060 KB] Hill climbing maximum PDB size: 80
# [t=0.01705s, 11060 KB] Hill climbing time: 0.0118705s
# [t=0.0172101s, 11060 KB] hill climbing pattern collection generator number of patterns: 4
# [t=0.0172646s, 11060 KB] hill climbing pattern collection generator total PDB size: 72
# [t=0.0172967s, 11060 KB] hill climbing pattern collection generator computation time: 0.0120996s
# [t=0.0173311s, 11060 KB] Running dominance pruning...
# [t=0.0173627s, 11060 KB] Pruned 3 of 4 pattern cliques
# [t=0.0173889s, 11060 KB] Pruned 3 of 4 PDBs
# [t=0.0174173s, 11060 KB] Dominance pruning took 8.5634e-05s
# [t=0.017453s, 11060 KB] Canonical PDB heuristic number of patterns: 1
# [t=0.0174826s, 11060 KB] Canonical PDB heuristic total PDB size: 40
# [t=0.0175119s, 11060 KB] Canonical PDB heuristic computation time: 0.0124779s
# [t=0.0175863s, 11060 KB] Building successor generator...done!
# [t=0.0177135s, 11060 KB] peak memory difference for successor generator creation: 0 KB
# [t=0.0177438s, 11060 KB] time for successor generation creation: 3.6056e-05s
# [t=0.0177796s, 11060 KB] Variables: 12
# [t=0.0178335s, 11060 KB] FactPairs: 27
# [t=0.0178758s, 11060 KB] Bytes per state: 4
# [t=0.0179487s, 11060 KB] Conducting best first search with reopening closed nodes, (real) bound = 2147483647
# [t=0.0180071s, 11060 KB] New best heuristic value for : 5
# [t=0.0180377s, 11060 KB] g=0, 1 evaluated, 0 expanded
# [t=0.0180671s, 11060 KB] f = 5, 1 evaluated, 0 expanded
# [t=0.0181009s, 11060 KB] Initial heuristic value for : 5
# [t=0.0181317s, 11060 KB] pruning method: none
# [t=0.0181836s, 11060 KB] f = 6, 3 evaluated, 1 expanded
# [t=0.0182261s, 11060 KB] New best heuristic value for : 4
# [t=0.0182562s, 11060 KB] g=2, 6 evaluated, 3 expanded
# [t=0.0182939s, 11060 KB] New best heuristic value for : 3
# [t=0.0183237s, 11060 KB] g=3, 8 evaluated, 4 expanded
# [t=0.0183619s, 11060 KB] f = 7, 9 evaluated, 5 expanded
# [t=0.0184212s, 11060 KB] f = 8, 16 evaluated, 10 expanded
# [t=0.0184839s, 11060 KB] f = 9, 24 evaluated, 15 expanded
# [t=0.0185417s, 11060 KB] f = 10, 29 evaluated, 19 expanded
# [t=0.0186272s, 11060 KB] New best heuristic value for : 2
# [t=0.0186663s, 11060 KB] g=8, 43 evaluated, 29 expanded
# [t=0.0187124s, 11060 KB] New best heuristic value for : 1
# [t=0.0187418s, 11060 KB] g=9, 47 evaluated, 30 expanded
# [t=0.0188023s, 11060 KB] New best heuristic value for : 0
# [t=0.0188342s, 11060 KB] g=10, 49 evaluated, 31 expanded
# [t=0.0188764s, 11060 KB] Solution found!
# [t=0.0189084s, 11060 KB] Actual search time: 0.000773532s
# pick_key_k  (1)
# open_k  (1)
# move_lr_k  (1)
# pick_key_all  (1)
# move_k_lr  (1)
# open_l  (1)
# move_lr_c  (1)
# open_c  (1)
# move_c_l  (1)
# open_f  (1)
# [t=0.0189455s, 11060 KB] Plan length: 10 step(s).
# [t=0.0189455s, 11060 KB] Plan cost: 10
# [t=0.0189455s, 11060 KB] Expanded 32 state(s).
# [t=0.0189455s, 11060 KB] Reopened 0 state(s).
# [t=0.0189455s, 11060 KB] Evaluated 49 state(s).
# [t=0.0189455s, 11060 KB] Evaluations: 49
# [t=0.0189455s, 11060 KB] Generated 104 state(s).
# [t=0.0189455s, 11060 KB] Dead ends: 0 state(s).
# [t=0.0189455s, 11060 KB] Expanded until last jump: 19 state(s).
# [t=0.0189455s, 11060 KB] Reopened until last jump: 0 state(s).
# [t=0.0189455s, 11060 KB] Evaluated until last jump: 29 state(s).
# [t=0.0189455s, 11060 KB] Generated until last jump: 56 state(s).
# [t=0.0189455s, 11060 KB] Number of registered states: 49
# [t=0.0189455s, 11060 KB] Int hash set load factor: 49/64 = 0.765625
# [t=0.0189455s, 11060 KB] Int hash set resizes: 6
# [t=0.0189455s, 11060 KB] Search time: 0.000998165s
# [t=0.0189455s, 11060 KB] Total time: 0.0189455s
# Solution found.
# Peak memory: 11060 KB
# Remove intermediate file output.sas
# search exit code: 0
#
# INFO     Planner time: 0.16s
# Found a plan of length: 10
# SequentialPlan:
#     Pick_Key_K
#     Open_K
#     move_LR_K
#     Pick_Key_all
#     move_K_LR
#     Open_L
#     move_LR_C
#     Open_C
#     move_C_L
#     Open_F
# Plan cost: {minimize actions-cost: {'default': 1}: 10}
